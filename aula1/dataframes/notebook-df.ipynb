# %%
import pandas as pd


# Criando um dict
data = {
    'Nome': ['Ana', 'Bruno', 'Carlos'], 
        # Colunas podem ter tipos diferentes entre sim
        # Porém dentro da coluna é só um tipo
    'Idade': [23, 35, 45], 
    'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte']
    }

# Transforma dict em dataframe
df = pd.DataFrame(data)
# print(df)

print("df.head(2)")
print(df.head(2))
print("df.tail(2)")
print(df.tail(2))
print("df.info()")
df.info()
print("df.describe()")
print(df.describe())
print("df.columns")
print(df.columns)
# Out:
# df.head(2)
#    Produto  Preço  Estoque
# 0    Mouse     80       45
# 1  Teclado    120       30
# df.tail(2)
#    Produto  Preço  Estoque
# 2  Monitor    900       12
# 3  Cadeira    450        8
# df.info()
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Produto  4 non-null      str
#  1   Preço    4 non-null      int64
#  2   Estoque  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes
# df.describe()
#             Preço    Estoque
# count    4.000000   4.000000
# mean   387.500000  23.750000
# std    379.769667  17.095321
# min     80.000000   8.000000
# 25%    110.000000  11.000000
# 50%    285.000000  21.000000
# 75%    562.500000  33.750000
# max    900.000000  45.000000
# df.columns
# Index(['Produto', 'Preço', 'Estoque'], dtype='str')

# %%
import pandas as pd

df = pd.read_csv('../vendas_modelo.csv')

# head retorna os primeiros 5 itens por padrão 
# e pode mudar o numero de itens por parametro
print(df.head(2))
# Out:
#    id_venda     produto  quantidade  preco_unitario
# 0         1       Mouse           4         3396.81
# 1         2  Smartphone           2         3684.08

# %%
import pandas as pd

df = pd.read_json('../estoque.json')

# head retorna os primeiros 5 itens por padrão 
# e pode mudar o numero de itens por parametro
print(df)
# Out:
#    id           produto  preco  estoque    categoria
# 0   1  Teclado Mecânico  250.0       15  Periféricos
# 1   2       Mouse Gamer  120.5       30  Periféricos
# 2   3     Monitor 24pol  890.0        8    Monitores
# 3   4       Headset USB  210.0       22        Áudio
# 4   5      Webcam 1080p  320.0       12   Acessórios
# 5   6    Cadeira Office  750.0        5       Móveis
# 6   7         SSD 480GB  280.0       45     Hardware
# 7   8   Memória RAM 8GB  190.0       60     Hardware
# 8   9      Cabo HDMI 2m   35.0      100   Acessórios
# 9  10   Suporte Monitor  110.0       18       Móveis

# %%
import pandas as pd

df = pd.read_json('../estoque-split.json', orient="split")

# head retorna os primeiros 5 itens por padrão 
# e pode mudar o numero de itens por parametro
print(df)
# Out:
#     id vendedor    vendas  meta_atingida        regiao
# 0  101    Alice  15200.50           True         Norte
# 1  102    Bruno   9800.00          False           Sul
# 2  103    Carla  12300.75           True       Sudeste
# 3  104    Diego   8500.00          False  Centro-Oeste
# 4  105    Elena  18900.20           True      Nordeste
# 5  106    Fabio  11000.00           True           Sul
# 6  107   Gisele   7200.40          False         Norte
# 7  108     Hugo  14500.00           True       Sudeste
# 8  109     Iara  10200.10          False      Nordeste
# 9  110     Joao  13100.00           True  Centro-Oeste

# %%
import pandas as pd

# O Pandas ignora o CSS e as divs, focando apenas na tag <table>
tabelas = pd.read_html('../site.html')
df = tabelas[0]

print(df.info())
print(df.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        10 non-null     int64
#  1   Vendedor  10 non-null     str
#  2   Vendas    10 non-null     float64
#  3   Regiao    10 non-null     str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 452.0 bytes
# None
#     ID Vendedor    Vendas        Regiao
# 0  101    Alice  15200.50         Norte
# 1  102    Bruno   9800.00           Sul
# 2  103    Carla  12300.75       Sudeste
# 3  104    Diego   8500.00  Centro-Oeste
# 4  105    Elena  18900.20      Nordeste

# %%
import pandas as pd

# O Pandas ignora o CSS e as divs, focando apenas na tag <table>
df = pd.read_xml('../inventario_produtos.xml')

print(df.head())
# Out:
#         SKU    Produto  Quantidade  Armazem  Preco_Unitario
# 0  PROD-001    Teclado          50   Lisboa            45.0
# 1  PROD-002       Rato         120    Porto            25.5
# 2  PROD-003    Monitor          15   Lisboa           180.0
# 3  PROD-004  Cabo HDMI         200  Coimbra            12.0
# 4  PROD-005     Webcam          30    Porto            55.0

# %%
dados = {
    'Produto': ['Mouse', 'Teclado', 'Monitor', 'Cadeira'],
    'Preco': [80, 120, 900, 450],
    'Estoque': [45, 30, 12, 8]
}
df = pd.DataFrame(dados)

df.to_csv('relatorio.csv', index=False)
df.to_json('relatorio.json', orient='records')

# %%
df = pd.read_json('relatorio.json')

print(df.head())
# Out:
#    Produto  Preco  Estoque
# 0    Mouse     80       45
# 1  Teclado    120       30
# 2  Monitor    900       12
# 3  Cadeira    450        8
